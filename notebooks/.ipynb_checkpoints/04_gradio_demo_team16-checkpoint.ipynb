# %% [markdown]
# # Notebook 04 - Gradio Demo (Singlish Marker Keyboard)
#
# **ITI113 Team 16 - Focus C (MLOps & Deployment).** Live demo for the presentation on 26 Aug.
#
# Self-contained: calls the deployed serverless endpoint `iti113-team16-singlish-keyboard` and wraps
# it in a Gradio UI. Model-agnostic, so it keeps working unchanged after the champion is swapped onto
# the same endpoint.
#
# Flow: one text box -> predicted sentence-final marker + top-3, with emoji rendered for the four
# mood groups (`emo_joy`, `emo_playful`, `emo_sad`, `emo_love`).
#
# **Requires `singlish_labelling.py` in this Studio folder** (same module the pipeline uses). The emoji
# map and the optional context-strip are both sourced from it, so nothing here can drift from training.
#
# > Backup recording is mandatory (sprint schedule). Record a screen capture the moment the live demo
# > works, in case the share link or endpoint wobbles on the day.

# %% [markdown]
# ## 0. Install

# %%
# !pip install -q gradio
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.5.0 requires nvidia-ml-py3<8.0,>=7.352.0, which is not installed.
# autogluon-timeseries 1.5.0 requires chronos-forecasting<2.4,>=2.2.2, which is not installed.
# autogluon-timeseries 1.5.0 requires einops<1,>=0.7, which is not installed.
# autogluon-timeseries 1.5.0 requires peft<0.18,>=0.13.0, which is not installed.
# autogluon-multimodal 1.5.0 requires fsspec[http]<=2025.3, but you have fsspec 2026.6.0 which is incompatible.
# transformers 4.57.6 requires huggingface-hub<1.0,>=0.34.0, but you have huggingface-hub 1.28.0 which is incompatible.

# %%
import gradio as gr
print(gr.__version__)
# Out:
# 6.25.0

# %% [markdown]
# ## 1. Config (self-contained)
#
# Same values as Notebook 03. No dependency on Notebook 03's kernel state.

# %%
import json
import boto3

REGION        = "ap-southeast-1"
ENDPOINT_NAME = "iti113-team16-singlish-keyboard"

rt = boto3.client("sagemaker-runtime", region_name=REGION)
print("Calling endpoint:", ENDPOINT_NAME, "in", REGION)
# Out:
# Calling endpoint: iti113-team16-singlish-keyboard in ap-southeast-1

# %% [markdown]
# ## 2. Endpoint call
#
# Request shape `{"text": "..."}`; response is a one-item list like
# `[{"prediction": "emo_joy", "top3": [{"marker": "emo_joy", "score": 0.41}, ...]}]`,
# matching `inference.py` in Notebook 03.
#
# **Train/serve note (optional toggle).** Training strips the sentence-final particle, so the model
# input X is the text *before* the marker. For the keyboard, the user has not typed the marker yet, so
# sending the raw typed text is the correct product behaviour, and it is what your deployed endpoint
# does. The one edge case is a demo typist who includes a trailing particle (e.g. `ok can lah`): then
# the features differ from training. `STRIP_CONTEXT = True` mirrors training exactly by removing a
# trailing particle client-side via the shared module. Default is `False` to match the endpoint you
# have already tested; flip it on if you want the stricter, train-consistent behaviour in the demo.

# %%
STRIP_CONTEXT = False  # True = mirror training (strip a trailing particle before sending)

if STRIP_CONTEXT:
    from singlish_labelling import strip_for_inference

def call_endpoint(text):
    """Invoke the live endpoint. Returns a dict with keys: prediction, top3."""
    payload_text = strip_for_inference(text) if STRIP_CONTEXT else text
    resp = rt.invoke_endpoint(
        EndpointName=ENDPOINT_NAME,
        ContentType="application/json",
        Body=json.dumps({"text": payload_text}),
    )
    out = json.loads(resp["Body"].read())
    return out[0] if isinstance(out, list) else out

# quick smoke test (run once; comment out before the live demo if you like)
print(call_endpoint("ok can"))
# Out:
# {'prediction': 'emo_joy', 'top3': [{'marker': 'emo_joy', 'score': 0.3102}, {'marker': 'lah', 'score': 0.2846}, {'marker': 'none', 'score': 0.1588}]}

# %% [markdown]
# ## 3. Label -> emoji mapping (sourced from the module)
#
# The four `emo_*` classes come straight from `EMOTICON_FAMILIES` in `singlish_labelling.py`, so this
# map cannot drift from the trained label space. `FAMILY_EMOJI` is the only hand-chosen part (a glyph
# per mood); an assertion guarantees every family is covered. Particles render as their own word, `none`
# shows muted, and any unexpected label falls back to a neutral glyph so the live demo never shows a blank.

# %%
from singlish_labelling import EMOTICON_FAMILIES

# One glyph per mood family. Edit glyphs to taste; keys are validated below.
FAMILY_EMOJI = {
    "joy":     "😄",
    "playful": "😜",
    "sad":     "😢",
    "love":    "❤️",
}
assert set(FAMILY_EMOJI) == set(EMOTICON_FAMILIES), (
    "FAMILY_EMOJI is out of sync with the module families: "
    f"{set(EMOTICON_FAMILIES) ^ set(FAMILY_EMOJI)}"
)

# emo_<family> -> glyph, derived from the module (authoritative)
EMOJI_BY_GROUP = {f"emo_{fam}": glyph for fam, glyph in FAMILY_EMOJI.items()}
print("emoji groups:", EMOJI_BY_GROUP)

def pretty(label):
    """Return (glyph, caption). glyph is empty for text-only markers (particles / none)."""
    if label is None or label == "none":
        return "", "no marker"
    if str(label).startswith("emo_"):
        return EMOJI_BY_GROUP.get(label, "🙂"), label.replace("emo_", "")
    return "", str(label)  # particle: the word itself is the suggestion

def render_label(label):
    """Single display string, e.g. '😄 joy', 'lah', '— none'."""
    glyph, caption = pretty(label)
    if glyph:
        return f"{glyph}  {caption}"
    return caption if label != "none" else "— none"
# Out:
# emoji groups: {'emo_joy': '😄', 'emo_playful': '😜', 'emo_sad': '😢', 'emo_love': '❤️'}

# %% [markdown]
# ## 4. Predict function for the UI

# %%
def predict_marker(text):
    text = (text or "").strip()
    if not text:
        return "Type a message first.", {}
    try:
        result = call_endpoint(text)
    except Exception as e:
        return f"Endpoint error: {e}", {}
    top_label = result.get("prediction", "none")
    glyph, caption = pretty(top_label)
    headline = f"{glyph}  {caption}".strip() if glyph else f"Suggested marker: {caption}"
    top3 = result.get("top3", [])
    scores = {render_label(d["marker"]): float(d["score"]) for d in top3}
    if not scores:
        scores = {render_label(top_label): 1.0}
    return headline, scores

# %% [markdown]
# ## 5. Gradio UI

# %%
import gradio as gr

with gr.Blocks(title="Team 16 - Singlish Marker Keyboard", theme=gr.themes.Soft()) as demo:
    gr.Markdown(
        "## Singlish Marker Keyboard\n"
        "Type a message. The model predicts the sentence-final marker: a Singlish particle "
        "(`lah` / `leh` / `lor`), a mood-grouped emoji, or none."
    )
    inp = gr.Textbox(label="Your message", placeholder="e.g. ok can", lines=2)
    btn = gr.Button("Predict marker", variant="primary")
    out_head = gr.Textbox(label="Top suggestion", interactive=False)
    out_top3 = gr.Label(label="Top-3 suggestions", num_top_classes=3)
    btn.click(predict_marker, inputs=inp, outputs=[out_head, out_top3])
    inp.submit(predict_marker, inputs=inp, outputs=[out_head, out_top3])
    gr.Examples(
        ["ok can", "so happy", "dunno why like that", "meeting at 3pm", "eh you free later"],
        inputs=inp,
    )

demo.launch(share=True)
# Out:
# /tmp/ipykernel_643/57244509.py:3: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme. Please pass these parameters to launch() instead.
#   with gr.Blocks(title="Team 16 - Singlish Marker Keyboard", theme=gr.themes.Soft()) as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://8721b89936935fabe6.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://8721b89936935fabe6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## 6. After it works
#
# 1. **Record the backup** (screen capture of the working demo). Mandatory fallback for the 26th.
# 2. Note the `share=True` public URL for the report and the submission ZIP (demo URL).
# 3. The share link expires after ~72 hours, so regenerate it near the presentation and keep the
#    recording as the true fallback.
# 4. When Ria's champion is chosen, redeploy it onto this same endpoint (delete + redeploy, one
#    endpoint per team). This notebook needs no change.
